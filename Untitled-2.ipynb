# %%
import pandas as pd 
import numpy as ny
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Swati\Downloads\ajit-data.zip")
df
# Out:
#                                                 img_url  \
# 0     https://cdn1.smartprix.com/rx-iab0UrrCY-w280-h...
# 1     https://cdn1.smartprix.com/rx-iGNlyOFEo-w280-h...
# 2     https://cdn1.smartprix.com/rx-ixLSVBm6G-w280-h...
# 3     https://cdn1.smartprix.com/rx-iCDx5JIUn-w280-h...
# 4     https://cdn1.smartprix.com/rx-iKWyXqzam-w280-h...
# ...                                                 ...
# 1015  https://cdn1.smartprix.com/rx-itSN7uCVS-w280-h...
# 1016  https://cdn1.smartprix.com/rx-i0iZiiCcP-w280-h...
# 1017  https://cdn1.smartprix.com/rx-ia91lMdn3-w280-h...
# 1018  https://cdn1.smartprix.com/rx-i1IP2RjxE-w280-h...
# 1019  https://cdn1.smartprix.com/rx-ingqawEhm-w280-h...
#
#                            name  spec_score  price (INR)  \
# 0                 OnePlus 11 5G          89        54999
# 1     OnePlus Nord CE 2 Lite 5G          81        18999
# 2         Samsung Galaxy A14 5G          75        16499
# 3          Motorola Moto G62 5G          81        14999
# ...

# %%
df_clean=df.dropna()
df
# Out:
#                                                 img_url  \
# 0     https://cdn1.smartprix.com/rx-iab0UrrCY-w280-h...
# 1     https://cdn1.smartprix.com/rx-iGNlyOFEo-w280-h...
# 2     https://cdn1.smartprix.com/rx-ixLSVBm6G-w280-h...
# 3     https://cdn1.smartprix.com/rx-iCDx5JIUn-w280-h...
# 4     https://cdn1.smartprix.com/rx-iKWyXqzam-w280-h...
# ...                                                 ...
# 1015  https://cdn1.smartprix.com/rx-itSN7uCVS-w280-h...
# 1016  https://cdn1.smartprix.com/rx-i0iZiiCcP-w280-h...
# 1017  https://cdn1.smartprix.com/rx-ia91lMdn3-w280-h...
# 1018  https://cdn1.smartprix.com/rx-i1IP2RjxE-w280-h...
# 1019  https://cdn1.smartprix.com/rx-ingqawEhm-w280-h...
#
#                            name  spec_score  price (INR)  \
# 0                 OnePlus 11 5G          89        54999
# 1     OnePlus Nord CE 2 Lite 5G          81        18999
# 2         Samsung Galaxy A14 5G          75        16499
# 3          Motorola Moto G62 5G          81        14999
# ...

# %%
df.drop_duplicates()
# Out:
#                                                 img_url  \
# 0     https://cdn1.smartprix.com/rx-iab0UrrCY-w280-h...
# 1     https://cdn1.smartprix.com/rx-iGNlyOFEo-w280-h...
# 2     https://cdn1.smartprix.com/rx-ixLSVBm6G-w280-h...
# 3     https://cdn1.smartprix.com/rx-iCDx5JIUn-w280-h...
# 4     https://cdn1.smartprix.com/rx-iKWyXqzam-w280-h...
# ...                                                 ...
# 1015  https://cdn1.smartprix.com/rx-itSN7uCVS-w280-h...
# 1016  https://cdn1.smartprix.com/rx-i0iZiiCcP-w280-h...
# 1017  https://cdn1.smartprix.com/rx-ia91lMdn3-w280-h...
# 1018  https://cdn1.smartprix.com/rx-i1IP2RjxE-w280-h...
# 1019  https://cdn1.smartprix.com/rx-ingqawEhm-w280-h...
#
#                            name  spec_score  price (INR)  \
# 0                 OnePlus 11 5G          89        54999
# 1     OnePlus Nord CE 2 Lite 5G          81        18999
# 2         Samsung Galaxy A14 5G          75        16499
# 3          Motorola Moto G62 5G          81        14999
# ...

# %%
df.duplicated
# Out:
# <bound method DataFrame.duplicated of                                                 img_url  \
# 0     https://cdn1.smartprix.com/rx-iab0UrrCY-w280-h...
# 1     https://cdn1.smartprix.com/rx-iGNlyOFEo-w280-h...
# 2     https://cdn1.smartprix.com/rx-ixLSVBm6G-w280-h...
# 3     https://cdn1.smartprix.com/rx-iCDx5JIUn-w280-h...
# 4     https://cdn1.smartprix.com/rx-iKWyXqzam-w280-h...
# ...                                                 ...
# 1015  https://cdn1.smartprix.com/rx-itSN7uCVS-w280-h...
# 1016  https://cdn1.smartprix.com/rx-i0iZiiCcP-w280-h...
# 1017  https://cdn1.smartprix.com/rx-ia91lMdn3-w280-h...
# 1018  https://cdn1.smartprix.com/rx-i1IP2RjxE-w280-h...
# 1019  https://cdn1.smartprix.com/rx-ingqawEhm-w280-h...
#
#                            name  spec_score  price (INR)  \
# 0                 OnePlus 11 5G          89        54999
# 1     OnePlus Nord CE 2 Lite 5G          81        18999
# 2         Samsung Galaxy A14 5G          75        16499
# ...

# %%
df.head()
# Out:
#                                              img_url  \
# 0  https://cdn1.smartprix.com/rx-iab0UrrCY-w280-h...
# 1  https://cdn1.smartprix.com/rx-iGNlyOFEo-w280-h...
# 2  https://cdn1.smartprix.com/rx-ixLSVBm6G-w280-h...
# 3  https://cdn1.smartprix.com/rx-iCDx5JIUn-w280-h...
# 4  https://cdn1.smartprix.com/rx-iKWyXqzam-w280-h...
#
#                         name  spec_score  price (INR)  \
# 0              OnePlus 11 5G          89        54999
# 1  OnePlus Nord CE 2 Lite 5G          81        18999
# 2      Samsung Galaxy A14 5G          75        16499
# 3       Motorola Moto G62 5G          81        14999
# 4         Realme 10 Pro Plus          82        24999
#
#                                        configuration
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC_Snapdr...
# 1  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi_Snapdragon ...
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi_Exynos 1330...
# 3  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi_Snapdragon ...
# ...

# %%
df.tail()
# Out:
#                                                 img_url             name  \
# 1015  https://cdn1.smartprix.com/rx-itSN7uCVS-w280-h...      Vivo V20 SE
# 1016  https://cdn1.smartprix.com/rx-i0iZiiCcP-w280-h...  Realme Narzo 20
# 1017  https://cdn1.smartprix.com/rx-ia91lMdn3-w280-h...         OPPO F17
# 1018  https://cdn1.smartprix.com/rx-i1IP2RjxE-w280-h...     Realme 7 Pro
# 1019  https://cdn1.smartprix.com/rx-ingqawEhm-w280-h...         Realme 7
#
#       spec_score  price (INR)  \
# 1015          82        19000
# 1016          72        10465
# 1017          78        16294
# 1018          82        19999
# 1019          78        15990
#
#                                           configuration
# 1015  Dual Sim, 3G, 4G, VoLTE, Wi-Fi_Snapdragon  665...
# 1016  Dual Sim, 3G, 4G, VoLTE, Wi-Fi_Helio G85 , Oct...
# 1017  Dual Sim, 3G, 4G, VoLTE, Wi-Fi_Snapdragon 662 ...
# 1018  Dual Sim, 3G, 4G, VoLTE, Wi-Fi_Snapdragon 720G...
# 1019  Dual Sim, 3G, 4G, VoLTE, Wi-Fi_Helio  G95, Oct...

# %%
df.columns [0:2]
# Out:
# Index(['img_url', 'name'], dtype='object')

# %%
df.dtypes
# Out:
# img_url          object
# name             object
# spec_score        int64
# price (INR)       int64
# configuration    object
# dtype: object

# %%
df.shape
# Out:
# (1020, 5)

# %%
df.shape[0]
# Out:
# 1020

# %%
df.shape[1]
# Out:
# 5
